# %%
import requests 

query_params = {
    "updated_min_timestamp" : "2023-05-01T00:00:00.00000Z", 
    "updated_max_timestamp" : "2023-05-01T23:59:59.99999Z", 
    "sell_token_address" : "0xacb3c6a43d15b907e8433077b6d38ae40936fe2c"
}

base_url = "https://api.x.immutable.com/v3/orders"
cursor = ""

response = requests.get(url=base_url) 
print(response.json())
# Out:
# {'result': [{'order_id': 307869631, 'status': 'active', 'user': '0x5964ea3a694c4ce36f90a294f768ea36290a4292', 'sell': {'type': 'ERC721', 'data': {'token_id': '242885485', 'id': '0x532b12a0bb68567f057f35220621cb2ec84a82ed986576f7f1049793206dd6ce', 'token_address': '0xacb3c6a43d15b907e8433077b6d38ae40936fe2c', 'quantity': '1', 'quantity_with_fees': '', 'properties': {'name': 'Atlant Phalanx', 'image_url': 'https://card.godsunchained.com/?id=1067&q=4', 'collection': {'name': 'Gods Unchained Cards', 'icon_url': 'https://images.godsunchained.com/misc/gu-sigel.png'}}}}, 'buy': {'type': 'ETH', 'data': {'token_address': '', 'decimals': 18, 'quantity': '9900000000000', 'quantity_with_fees': '10593000000000'}}, 'amount_sold': None, 'expiration_timestamp': '2122-07-17T17:00:00Z', 'timestamp': '2023-07-17T17:31:59.199036Z', 'updated_timestamp': '2023-07-17T17:31:59.199036Z', 'maker_taker_type': 'maker', 'maker_fees': {'quantity_with_fees': '9900000000000', 'token_type': 'ETH', 'decimals': 18, 's
# ...
